# %%
import numpy as np
import pandas as pd
import warnings 
warnings.filterwarnings("ignore")

# %%
Hr=pd.read_csv(r"C:\Users\Ramakrishna\Desktop\HR employee Analyst\Uncleaned_employees_final_dataset.csv")

# %%
Hr
# Out:
#        employee_id         department     region  education gender  \
# 0             8724         Technology  region_26  Bachelors      m
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17414        49584                 HR   region_7  Bachelors      m
# 17415        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   NaN
# ...

# %% [markdown]
# ## Removing duplicate rows

# %%
Hr.duplicated().sum()
# Out:
# 2

# %%
Hr=Hr.drop_duplicates()

# %%
Hr.duplicated().sum()
# Out:
# 0

# %%
Hr
# Out:
#        employee_id         department     region  education gender  \
# 0             8724         Technology  region_26  Bachelors      m
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17410        57239  Sales & Marketing  region_31  Bachelors      m
# 17411        73858  Sales & Marketing  region_25  Bachelors      m
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   NaN
# ...

# %% [markdown]
# ## Step 2: Removing rows for which numeric columns are having irrelevant data type values

# %%
Hr.isna().sum()
# Out:
# employee_id                 0
# department                  0
# region                      0
# education                 771
# gender                      0
# recruitment_channel         0
# no_of_trainings             0
# age                         0
# previous_year_rating     1363
# length_of_service           0
# KPIs_met_more_than_80       0
# awards_won                  0
# avg_training_score          0
# dtype: int64

# %%
Hr.dropna(inplace=True)

# %%
Hr.isna().sum()
# Out:
# employee_id              0
# department               0
# region                   0
# education                0
# gender                   0
# recruitment_channel      0
# no_of_trainings          0
# age                      0
# previous_year_rating     0
# length_of_service        0
# KPIs_met_more_than_80    0
# awards_won               0
# avg_training_score       0
# dtype: int64

# %%
Hr.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met_more_than_80', 'awards_won',
#        'avg_training_score'],
#       dtype='object')

# %%
Hr=Hr[Hr.employee_id !="irrelevent_data"]
Hr=Hr[Hr.department !="irrelevent_data"]
Hr=Hr[Hr.region !="irrelevent_data"]
Hr=Hr[Hr.gender !="irrelevent_data"]
Hr=Hr[Hr.recruitment_channel !="irrelevent_data"]
Hr=Hr[Hr.no_of_trainings !="irrelevent_data"]
Hr=Hr[Hr.age !="irrelevent_data"]
Hr=Hr[Hr.previous_year_rating !="irrelevent_data"]
Hr=Hr[Hr.length_of_service !="irrelevent_data"]
Hr=Hr[Hr.KPIs_met_more_than_80 !="irrelevent_data"]
Hr=Hr[Hr.awards_won !="irrelevent_data"]
Hr=Hr[Hr.avg_training_score !="irrelevent_data"]

# %%
Hr['region']=Hr['region'].str.replace('_',' ')

# %%
Hr.to_csv("employee.csv",encoding="utf-8")

# %% [markdown]
# ## Remove irrelevant values from each column if any. Validation of all values for a column Check for any inconsistencies or discrepancies in data types, units, or formats. feel free to add more validation checks which you might feel necessary for the dataset’s integrity
